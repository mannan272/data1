# %% [markdown]
# ## Assignment 3
#
# **TU Delft and WUR**<br>
# **Q1 2024**<br>
# **Instructor:** Theodoros Chatzivasileiadis <br>
# **Instructor:** Hans Hoogenboom <br>
# **TA:** Ka Yi Chua <br>
# **[Metropolitan Data 1](https://jhoogenboom.github.io/spatial-data-science/_index.html)** <br>

# %% [markdown]
# __This homework assignment document will guide you through five tasks in cleaning your data.__
#
# 1. Reading and Summarizing the Data.
# 2. Subsetting the Data.
# 3. Manage Missing Data.
# 4. Shape the Data.
# 5. Saving the Results.
#
# # NB: From now on you should submit 1) your notebook with the answers, remember that comments are good practice, 2) a working Git page with your assignment

# %% [markdown]
# ## Exercise 1: Loading the data:
#
# - Load the `goodreads.csv` file into Python
# - Explore it by looking at first and last 5 rows
# - Change the column names to `["rating", 'review_count', 'isbn', 'booktype','author_url', 'year', 'genre_urls', 'dir','rating_count', 'name']`

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# loading the csv document with pd.read_cvs('')

document= pd.read_csv('C:/Users/renee/OneDrive - De Haagse Hogeschool/Documenten/Master Made/MADE MASTER/DATA 1/reneev/lab-02/data/goodreads.csv')

# %%
#with document shape, it shows how large the file is and if we need to transfer it to the first 5 and last 5
document.shape
# Out:
# (5999, 10)

# %%
#show the first 5 rows by the next code
document.head()
# Out:
#    4.40   136455  0439023483  good_reads:book  \
# 0  4.41  16648.0  0439358078  good_reads:book
# 1  3.56  85746.0  0316015849  good_reads:book
# 2  4.23  47906.0  0061120081  good_reads:book
# 3  4.23  34772.0  0679783261  good_reads:book
# 4  4.25  12363.0  0446675539  good_reads:book
#
#   https://www.goodreads.com/author/show/153394.Suzanne_Collins    2008  \
# 0  https://www.goodreads.com/author/show/1077326....            2003.0
# 1  https://www.goodreads.com/author/show/941441.S...            2005.0
# 2  https://www.goodreads.com/author/show/1825.Har...            1960.0
# 3  https://www.goodreads.com/author/show/1265.Jan...            1813.0
# 4  https://www.goodreads.com/author/show/11081.Ma...            1936.0
#
#   /genres/young-adult|/genres/science-fiction|/genres/dystopia|/genres/fantasy|/genres/science-fiction|/genres/romance|/genres/adventure|/genres/book-club|/genres/young-adult|/genres/teen|/genres/apocalyptic|/genres/post-apocalyptic|/genres/action  \
# ...

# %%
# show both the first and the last 5 rows of the dataset by simply putting down the functionname of the csv file
document
#this is a structured dataframe
# Out:
#       4.40   136455  0439023483  good_reads:book  \
# 0     4.41  16648.0  0439358078  good_reads:book
# 1     3.56  85746.0  0316015849  good_reads:book
# 2     4.23  47906.0  0061120081  good_reads:book
# 3     4.23  34772.0  0679783261  good_reads:book
# 4     4.25  12363.0  0446675539  good_reads:book
# ...    ...      ...         ...              ...
# 5994  4.17   2226.0  0767913736  good_reads:book
# 5995  3.99    775.0  1416909427  good_reads:book
# 5996  3.78    540.0  1620612321  good_reads:book
# 5997  3.91    281.0         NaN  good_reads:book
# 5998  4.35     61.0  0786929081  good_reads:book
#
#      https://www.goodreads.com/author/show/153394.Suzanne_Collins    2008  \
# 0     https://www.goodreads.com/author/show/1077326....            2003.0
# 1     https://www.goodreads.com/author/show/941441.S...            2005.0
# 2     https://www.goodreads.com/author/show/1825.Har...            1960.0
# 3     https://www.goodreads.com/author/show/1265.Jan...            1813.0
# ...

# %%
#by printing the data, there is a list printed of the data. 
print (document)
# Out:
#       4.40   136455  0439023483  good_reads:book  \
# 0     4.41  16648.0  0439358078  good_reads:book
# 1     3.56  85746.0  0316015849  good_reads:book
# 2     4.23  47906.0  0061120081  good_reads:book
# 3     4.23  34772.0  0679783261  good_reads:book
# 4     4.25  12363.0  0446675539  good_reads:book
# ...    ...      ...         ...              ...
# 5994  4.17   2226.0  0767913736  good_reads:book
# 5995  3.99    775.0  1416909427  good_reads:book
# 5996  3.78    540.0  1620612321  good_reads:book
# 5997  3.91    281.0         NaN  good_reads:book
# 5998  4.35     61.0  0786929081  good_reads:book
#
#      https://www.goodreads.com/author/show/153394.Suzanne_Collins    2008  \
# 0     https://www.goodreads.com/author/show/1077326....            2003.0
# 1     https://www.goodreads.com/author/show/941441.S...            2005.0
# 2     https://www.goodreads.com/author/show/1825.Har...            1960.0
# 3     https://www.goodreads.com/author/show/1265.Jan...            1813.0
# ...

# %%
#Changing the names of the columns
newdocument= pd.read_csv('C:/Users/renee/OneDrive - De Haagse Hogeschool/Documenten/Master Made/MADE MASTER/DATA 1/reneev/lab-02/data/goodreads.csv',header=None,names=["rating", 'review_count', 'isbn', 'booktype','author_url', 'year', 'genre_urls', 'dir','rating_count', 'name'] )

#you only have to print the first few rows to see if the titles are changed, so you can print document.head()
newdocument.head()
# Out:
#    rating  review_count        isbn         booktype  \
# 0    4.40      136455.0  0439023483  good_reads:book
# 1    4.41       16648.0  0439358078  good_reads:book
# 2    3.56       85746.0  0316015849  good_reads:book
# 3    4.23       47906.0  0061120081  good_reads:book
# 4    4.23       34772.0  0679783261  good_reads:book
#
#                                           author_url    year  \
# 0  https://www.goodreads.com/author/show/153394.S...  2008.0
# 1  https://www.goodreads.com/author/show/1077326....  2003.0
# 2  https://www.goodreads.com/author/show/941441.S...  2005.0
# 3  https://www.goodreads.com/author/show/1825.Har...  1960.0
# 4  https://www.goodreads.com/author/show/1265.Jan...  1813.0
#
#                                           genre_urls  \
# 0  /genres/young-adult|/genres/science-fiction|/g...
# 1  /genres/fantasy|/genres/young-adult|/genres/fi...
# 2  /genres/young-adult|/genres/fantasy|/genres/ro...
# 3  /genres/classics|/genres/fiction|/genres/histo...
# ...

# %% [markdown]
# ## Exercise 2: Subsetting the data
#
# - Subset the data by creating new dataframe only with `["rating", 'isbn', 'author_url', 'year', 'genre_urls', 'name']`

# %%
#make a NEW dataframe with of `["rating", 'isbn', 'author_url', 'year', 'genre_urls', 'name']`
#there are double brackets to day that we want to impleent multiple columns in the new dataframe
newdataframe = newdocument[["rating", 'isbn', 'author_url', 'year', 'genre_urls', 'name']]

newdataframe.head()
# Out:
#    rating        isbn                                         author_url  \
# 0    4.40  0439023483  https://www.goodreads.com/author/show/153394.S...
# 1    4.41  0439358078  https://www.goodreads.com/author/show/1077326....
# 2    3.56  0316015849  https://www.goodreads.com/author/show/941441.S...
# 3    4.23  0061120081  https://www.goodreads.com/author/show/1825.Har...
# 4    4.23  0679783261  https://www.goodreads.com/author/show/1265.Jan...
#
#      year                                         genre_urls  \
# 0  2008.0  /genres/young-adult|/genres/science-fiction|/g...
# 1  2003.0  /genres/fantasy|/genres/young-adult|/genres/fi...
# 2  2005.0  /genres/young-adult|/genres/fantasy|/genres/ro...
# 3  1960.0  /genres/classics|/genres/fiction|/genres/histo...
# 4  1813.0  /genres/classics|/genres/fiction|/genres/roman...
#
#                                                 name
# 0            The Hunger Games (The Hunger Games, #1)
# ...

# %% [markdown]
# ## Exercise 3: Manage Missing Data
# We’ve got a number of ways in general of dealing with missing data. These involve
#
# 1. Dropping off cases (or rows) in the data with any missing variables
# 2. Excluding variables in the data with any missing data
# 3. Selectively choosing indicators with only a limited amount of missing data
# 4. Replacing missing variables with averages, or other representative values
# 5. Creating a separate model to predict missing data
#
# - Count the missing values in each column
# - Manage the missing values (delete or replace values or leave them as they are) and briefly explain your choice for each column

# %%
# count the missing values in each column
# by putting in the name of the file + pd.isnull you wil reach the data that has NaN (Not an number) from the selected column
newdocument[pd.isnull(newdocument.isbn)]
# Out:
#       rating  review_count isbn         booktype  \
# 16      3.92       38061.0  NaN  good_reads:book
# 49      3.85       11628.0  NaN  good_reads:book
# 85      4.16       14968.0  NaN  good_reads:book
# 116     3.92        8393.0  NaN  good_reads:book
# 156     4.03        3473.0  NaN  good_reads:book
# ...      ...           ...  ...              ...
# 5972    4.19        1670.0  NaN  good_reads:book
# 5976    4.23        1185.0  NaN  good_reads:book
# 5977    4.03         218.0  NaN  good_reads:book
# 5991    4.20         650.0  NaN  good_reads:book
# 5998    3.91         281.0  NaN  good_reads:book
#
#                                              author_url    year  \
# 16    https://www.goodreads.com/author/show/498072.A...  2003.0
# 49    https://www.goodreads.com/author/show/5152.Vla...  1955.0
# 85    https://www.goodreads.com/author/show/137902.R...  2007.0
# 116   https://www.goodreads.com/author/show/957894.A...  1942.0
# ...

# %%
#the one above shows the NaN of 1 column, now we want to COUNT the NaN values 
#make a new function for missing values & the sum of isnull
missing_values_count = newdocument.isnull().sum()

# print the sum you made of the missing values for each column
print(missing_values_count)
# Out:
# rating            2
# review_count      2
# isbn            477
# booktype          2
# author_url        2
# year              7
# genre_urls       62
# dir               0
# rating_count      2
# name              2
# dtype: int64

# %%
#isbn is an identificationcode and not replacable, so we need to delete the rows
newdocument = newdocument.dropna(subset=['isbn'])

#The rating can be filled with the mean of the file, so first sort out the mean and after fill in the mean 
mean_rating = newdocument['rating'].mean()
newdocument['rating'] = newdocument['rating'].fillna(mean_rating)

#As you can see, the only missing values are genre URLs and 1x the year of a book
newdocument['genre_urls'] = newdocument['genre_urls'].fillna('No URL')
missing_values_count = newdocument.isnull().sum()
print(missing_values_count)
# Out:
# rating          0
# review_count    0
# isbn            0
# booktype        0
# author_url      0
# year            1
# genre_urls      0
# dir             0
# rating_count    0
# name            0
# dtype: int64

# %%
#only the year is missing, but i can not gues nor delete the information. So the year of the book is a missing data

# %% [markdown]
# ## Exercise 4: Shape the data
# - Parse the `author_url` to create new column named `author`
# - Sort the data by putting higher rates go first. If there are overlapping rates, try to put earlier years go first.
# - **(Stretch Goal)** Examine how many books were published at each year and find lowest, highest rate of each year.

# %%
#  Parse the `author_url` to create new column named `author`
#first test where the authors name is in the url and what you should do to only get the name 

test_string = newdocument.author_url[4]
test_string
# Out:
# 'https://www.goodreads.com/author/show/1265.Jane_Austen'

# %%
author=newdocument.author_url

# %%
#Try string operations to isolate the author name
#the sentence below explains that the author_url of the newdocument needs to split

test_string.split('/')[-1].split('.')[1:][0]
# Out:
# 'Jane_Austen'

# %%
def get_author(url):

    name = url.split('/')[-1].split('.')[1:][0]
     
    return name

# %%
newdocument['author'] = newdocument.author_url.map(get_author)
newdocument.author[0:5]
# Out:
# 0    Suzanne_Collins
# 1        J_K_Rowling
# 2    Stephenie_Meyer
# 3         Harper_Lee
# 4        Jane_Austen
# Name: author, dtype: object

# %%
newdocument['genres']=newdocument.genre_urls.map
newdocument.head()
# Out:
#    rating  review_count        isbn         booktype  \
# 0    4.40      136455.0  0439023483  good_reads:book
# 1    4.41       16648.0  0439358078  good_reads:book
# 2    3.56       85746.0  0316015849  good_reads:book
# 3    4.23       47906.0  0061120081  good_reads:book
# 4    4.23       34772.0  0679783261  good_reads:book
#
#                                           author_url    year  \
# 0  https://www.goodreads.com/author/show/153394.S...  2008.0
# 1  https://www.goodreads.com/author/show/1077326....  2003.0
# 2  https://www.goodreads.com/author/show/941441.S...  2005.0
# 3  https://www.goodreads.com/author/show/1825.Har...  1960.0
# 4  https://www.goodreads.com/author/show/1265.Jan...  1813.0
#
#                                           genre_urls  \
# 0  /genres/young-adult|/genres/science-fiction|/g...
# 1  /genres/fantasy|/genres/young-adult|/genres/fi...
# 2  /genres/young-adult|/genres/fantasy|/genres/ro...
# 3  /genres/classics|/genres/fiction|/genres/histo...
# ...

# %%
#  Sort the data by putting higher rates go first. If there are overlapping rates, try to put earlier years go first.
# Reset the index and drop the old one
newdocument = newdocument.reset_index(drop=True)

# Sort values by the 'rates' column (check if 'rates' exists)
if 'rating' in newdocument.columns:
    newdocument = newdocument.sort_values(by='rating', ascending=True)  # Default is ascending
else:
    print("'rates' column not found")

# %%
#check if the sorting is correct
newdocument.head()
# Out:
#       index  rating  review_count        isbn         booktype  \
# 3488   3738    2.00         368.0  0983650322  good_reads:book
# 5504   5979    2.77         800.0  0060988649  good_reads:book
# 5383   5844    2.97        1399.0  0395083621  good_reads:book
# 4736   5113    3.01        3072.0  0452286530  good_reads:book
# 4689   5064    3.03         485.0  1416523723  good_reads:book
#
#                                              author_url    year  \
# 3488  https://www.goodreads.com/author/show/9414.Vic...  2011.0
# 5504  https://www.goodreads.com/author/show/7025.Gre...  2001.0
# 5383  https://www.goodreads.com/author/show/30691.Ad...  1925.0
# 4736  https://www.goodreads.com/author/show/1448.Kar...  2004.0
# 4689  https://www.goodreads.com/author/show/1624.Her...  1924.0
#
#                                              genre_urls  \
# 3488  /genres/young-adult|/genres/science-fiction|/g...
# 5504  /genres/fantasy|/genres/fiction|/genres/myster...
# ...

# %% [markdown]
# ## Exercise 5: Saving the results
# - Save the cleaned dataframe as 'hw-03-cleaned.csv' in data folder

# %%
import os
#the os module makes sure the data folder exists before saving it

# %%
# save the cleaned dataframe as 'hw-03-cleaned.csv' in data folder
# say if this does not exist yet, make it exist. Dave the new document to the 'data/hw-03-cleaned.cvs)
#
if not os.path.exists('data'):
    os.makedirs('data')

newdocument.to_csv('data/hw-03-cleaned.csv', index=False)
print("DataFrame saved as 'hw-03-cleaned.csv' in the 'data' folder.")
#print to make sure the file is saved and there it is saved
# Out:
# DataFrame saved as 'hw-03-cleaned.csv' in the 'data' folder.

# %% [markdown]
# ## Exercise 6: Investigate the relationship between the number of reviews and the average rating for books in the dataset cleaned-goodreads.csv procided.
#
# - Calculate the correlation coefficient. Give me a short definition of this coefficient
# - Create a scatter plot showing the relationship between these two features.
# - Based on the plot and the correlation, provide a brief interpretation of the relationship.
#
# ### Python Tools: Use pandas and numpy for correlation, and matplotlib or seaborn for the scatter plot.

# %%
import numpy as np
newdocument.head()
# Out:
#    index  rating  review_count        isbn         booktype  \
# 0   3738    2.00         368.0  0983650322  good_reads:book
# 1   5979    2.77         800.0  0060988649  good_reads:book
# 2   5844    2.97        1399.0  0395083621  good_reads:book
# 3   5113    3.01        3072.0  0452286530  good_reads:book
# 4   5064    3.03         485.0  1416523723  good_reads:book
#
#                                           author_url    year  \
# 0  https://www.goodreads.com/author/show/9414.Vic...  2011.0
# 1  https://www.goodreads.com/author/show/7025.Gre...  2001.0
# 2  https://www.goodreads.com/author/show/30691.Ad...  1925.0
# 3  https://www.goodreads.com/author/show/1448.Kar...  2004.0
# 4  https://www.goodreads.com/author/show/1624.Her...  1924.0
#
#                                           genre_urls  \
# 0  /genres/young-adult|/genres/science-fiction|/g...
# 1  /genres/fantasy|/genres/fiction|/genres/myster...
# 2  /genres/history|/genres/non-fiction|/genres/bi...
# ...

# %%
# Calculate the correlation coefficient. Give me a short definition of this coefficient
#calculating correlation with pandas by printing the dataset colums of rating an review count with a correlation mark in between.
print(newdocument['rating'].corr(newdocument['review_count']))
# Out:
# -0.029283741930468937

# %%
#Create a scatter plot showing the relationship between these two features.
x=newdocument['rating']
y=newdocument['review_count']

plt.scatter(x, y)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Relation between Review Count & Rating')
plt.xlabel('rating')
plt.ylabel('review count')
plt.show()

# %%
#- Based on the plot and the correlation, provide a brief interpretation of the relationship.
# The scatterplot shows that the ratings go up when the revieuw count is higher around 4.0& 4.5. After the 4.5 there is not an correlation that im aware of. 
# The books that have a high review count have a good rating. 
# the relationship between the two is not linear.

# %% [markdown]
# ## Exercise 7: Calculate the following descriptive statistics for the numerical features (e.g., number of reviews, average rating, etc.):
# - Mean
# - Median
# - Standard Deviation
# - Range
# - Create a histogram or box plot for at least one of the numerical features, highlighting any skewness or outliers.
#
# ### Python Tools: Use pandas for data manipulation and matplotlib or seaborn for visualization.

# %%
# mean number of reviews, average rating, year, rating count
mean_rating = newdocument['rating'].mean()
mean_reviewcount= newdocument['review_count'].mean()
mean_year= newdocument['year'].mean()
mean_ratingcount= newdocument['rating_count'].mean()
print(mean_rating,mean_reviewcount,mean_year,mean_ratingcount)
# Out:
# 4.0300742350172 2448.5299655984068 1966.3889894965591 53758.58844830708

# %%
#median
median_rating = newdocument['rating'].median()
median_reviewcount= newdocument['review_count'].median()
median_year= newdocument['year'].median()
median_ratingcount= newdocument['rating_count'].median()
print(median_rating,median_reviewcount,median_year,median_ratingcount)
# Out:
# 4.04 957.0 2001.0 19093.0

# %%
#standard deviation
import statistics
from statistics import stdev

std_devrating = np.std(newdocument['rating'])
std_devreviewcount = np.std(newdocument['review_count'])
std_devyear = np.std(newdocument['year'])
std_devratingcount = np.std(newdocument['rating_count'])


print(std_devrating,std_devreviewcount,std_devyear,std_devratingcount)
# Out:
# 0.25315473572092784 5657.183790123208 191.53776116833845 142161.65032350854

# %%
range_rating = newdocument['rating'].max() - newdocument['rating'].min()
range_reviewcount = newdocument['review_count'].max() - newdocument['review_count'].min()
range_year = newdocument['year'].max() - newdocument['year'].min()
range_ratingcount = newdocument['rating_count'].max() - newdocument['rating_count'].min()

# Print the calculated ranges
print("Range of Rating:", range_rating)
print("Range of Review Count:", range_reviewcount)
print("Range of Year:", range_year)
print("Range of Rating Count:", range_ratingcount)
# Out:
# Range of Rating: 3.0
# Range of Review Count: 136455.0
# Range of Year: 3514.0
# Range of Rating Count: 2958968.0

# %%
plt.hist(newdocument['rating'], bins=30, color='green', edgecolor='black')
plt.title('Distribution rating')
plt.xlabel('rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(newdocument['rating'], vert=False, patch_artist=True)
plt.title('Box Plot of rating')
plt.xlabel('rating')
plt.show()
