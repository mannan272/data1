# %% [markdown]
# # <img style="float: left; padding-right: 10px; width: 200px" src="https://raw.githubusercontent.com/trivikverma/researchgroup/master/assets/media/logo.png"> Hackathon 2024
#
# **Team 13**<br>
# **Mannan Gupta | Haksan Sadak | Nils Hollestelle | Edwin smits | Renee Lam**<br>
#
# ---

# %% [markdown]
# ## Step 1: Loading libraries
# ### lorem impsum
#
# lorem impsum

# %%
# your code here 
import seaborn as sns
import pandas as pd
from pysal.lib import weights
from pysal.explore import esda
from splot.esda import moran_scatterplot, lisa_cluster, plot_local_autocorrelation
import geopandas as gpd
import numpy as np
import contextily as ctx
import matplotlib.pyplot as plt
# Out:
# Matplotlib created a temporary cache directory at /var/folders/hh/9p38b7xx6b50mvzqx94q5p_80000gn/T/matplotlib-g80zjeqt because the default path (/Users/nilshollestelle/.matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# /Users/nilshollestelle/miniconda3/lib/python3.12/site-packages/spaghetti/network.py:41: FutureWarning: The next major release of pysal/spaghetti (2.0.0) will drop support for all ``libpysal.cg`` geometries. This change is a first step in refactoring ``spaghetti`` that is expected to result in dramatically reduced runtimes for network instantiation and operations. Users currently requiring network and point pattern input as ``libpysal.cg`` geometries should prepare for this simply by converting to ``shapely`` geometries.
#   warnings.warn(dep_msg, FutureWarning, stacklevel=1)

# %% [markdown]
# ## 2. Loading data
#
# ### a. Parking

# %%
df_parking = pd.read_excel('data/Traffic.xlsx','data', index_col = 'Area code')

df_parking.head()
# Out:
#           Geography                     Area  Year    theme  \
# Area code
# AA           Wijken          Haarlemmerbuurt  2021  Traffic
# AB           Wijken                  Jordaan  2021  Traffic
# AC           Wijken      Grachtengordel-West  2021  Traffic
# AD           Wijken  Burgwallen-Nieuwe Zijde  2021  Traffic
# AE           Wijken    Burgwallen-Oude Zijde  2021  Traffic
#
#           Nuisance: speeding traffic (%)  \
# Area code
# AA                                    15
# AB                                    17
# AC                                    20
# AD                                    18
# AE                                    13
#
#           Nuisance: aggressive behaviour in traffic (%)  \
# Area code
# AA                                                   10
# AB                                                   16
# AC                                                   16
# AD                                                   12
# AE                                                   21
#
#           Nuisance: parking problems (%)  Parking spots total  \
# Area code
# AA                                    10                 1112
# AB                                    21                 2711
# AC                                    21                 1338
# AD                                    16                  619
# AE                                    22                  310
#
#           Parking spots fiscal  Parking spots non public  \
# Area code
# AA                         952                       160
# AB                        2409                       302
# AC                        1218                       120
# AD                         382                       237
# AE                         211                        99
#
#           Parking facilities (1-10) Parking facilities bikes (1-10)  \
# Area code
# AA                              5.9                             5.7
# AB                              5.5                             5.1
# AC                              5.4                             5.4
# AD                              5.5                             5.6
# AE                              5.2                             5.9
#
#           Nuisance: parking (1-10) Public transport (1-10)  \
# Area code
# AA                             6.9                     7.6
# AB                             6.5                     7.7
# AC                             6.2                     7.9
# AD                               7                     8.5
# AE                             6.6                     8.5
#
#           Public transport 65+ (1-10) Nuisance: amount of traffic (1-10)  \
# Area code
# AA                                7.3                                6.8
# AB                                7.5                                6.6
# AC                                7.7                                6.8
# AD                                7.9                                6.4
# AE                                8.6                                6.7
#
#           Nuisance: traffic noise (1-10) Parking spots non-fiscal
# Area code
# AA                                   6.8                        -
# AB                                   6.8                        -
# AC                                   6.8                        -
# AD                                   6.2                        -
# AE                                   6.9                        -

# %% [markdown]
# ### b. Housing

# %%
df_housing = pd.read_excel('data/Housing.xlsx','data', index_col = 'Area code')

df_housing.head()
# Out:
#           Geography                     Area  Year    theme  Housing stock  \
# Area code
# AA           Wijken          Haarlemmerbuurt  2021  Housing           5654
# AB           Wijken                  Jordaan  2021  Housing          13217
# AC           Wijken      Grachtengordel-West  2021  Housing           4316
# AD           Wijken  Burgwallen-Nieuwe Zijde  2021  Housing           2972
# AE           Wijken    Burgwallen-Oude Zijde  2021  Housing           2974
#
#           Housing density Trailer space Mooring place  \
# Area code
# AA                  10558             4           135
# AB                  15870             1           113
# AC                   9638             1            75
# AD                   5302             1            13
# AE                   8535             -             3
#
#           Sheltered accommodations Property: Housing corporation  ...  \
# Area code                                                         ...
# AA                              38                          2341  ...
# AB                               6                          4832  ...
# AC                               9                           462  ...
# AD                               5                           289  ...
# AE                              12                           572  ...
#
#            Wish to move 65+ (%)  \
# Area code
# AA                           16
# AB                           14
# AC                           13
# AD                            -
# AE                            -
#
#           Neighbourhood: Satisfaction with neighbourhood (1-10)  \
# Area code
# AA                                                       8.2
# AB                                                       8.2
# AC                                                       8.4
# AD                                                       7.2
# AE                                                       7.3
#
#           Neighbourhood: pleasant to live (1-10)  \
# Area code
# AA                                             8
# AB                                           7.8
# AC                                             8
# AD                                           7.5
# AE                                           7.1
#
#           Neighbourhood: Expected development (1-10)  \
# Area code
# AA                                               7.2
# AB                                                 7
# AC                                                 7
# AD                                               6.6
# AE                                               6.6
#
#            Neighbourhood: % improved Neighbourhood: % stayed the same  \
# Area code
# AA                                14                               65
# AB                                15                               62
# AC                                13                               64
# AD                                26                               47
# AE                                32                               40
#
#           Neighbourhood: % deteriorated Neighbourhood: feeling at home (1-10)  \
# Area code
# AA                                   16                                   8.3
# AB                                   18                                   8.3
# AC                                   19                                   8.4
# AD                                   18                                   7.7
# AE                                   22                                   7.8
#
#           Involvement neighbours (1-10)  Rent: average in commercial sector
# Area code
# AA                                  6.7                                   -
# AB                                  6.8                                1414
# AC                                  6.6                                   -
# AD                                  5.7                                1434
# AE                                  6.5                                   -
#
# [5 rows x 67 columns]

# %% [markdown]
# ### c. Population

# %%
df_population = pd.read_excel('data/Population.xlsx','data', index_col = 'Area code')
df_population.head()
# Out:
#           Geography                     Area  Year       theme  Population  \
# Area code
# AA           Wijken          Haarlemmerbuurt  2021  Population        9171
# AB           Wijken                  Jordaan  2021  Population       19403
# AC           Wijken      Grachtengordel-West  2021  Population        6366
# AD           Wijken  Burgwallen-Nieuwe Zijde  2021  Population        4026
# AE           Wijken    Burgwallen-Oude Zijde  2021  Population        4525
#
#            Gender: male  Gender: female  Gender: % male  Gender: % female  \
# Area code
# AA                 4619            4552            50.4              49.6
# AB                 9836            9567            50.7              49.3
# AC                 3331            3035            52.3              47.7
# AD                 2228            1798            55.3              44.7
# AE                 2486            2039            54.9              45.1
#
#           Population density  ... Main resident 18-66 Population: births  \
# Area code                     ...
# AA                     17126  ...                4491                 79
# AB                     23298  ...               10467                172
# AC                     14217  ...                3239                 57
# AD                      7182  ...                2523                 30
# AE                     12986  ...                2774                 33
#
#           Population: deaths  Population: arrivals from outside the city  \
# Area code
# AA                        67                                         726
# AB                       142                                        1652
# AC                        28                                         978
# AD                         9                                         834
# AE                        21                                         697
#
#            Population: departures  from the city  \
# Area code
# AA                                           711
# AB                                          1466
# AC                                           665
# AD                                           538
# AE                                           537
#
#            Population: arrivals from Amsterdam (other area)  \
# Area code
# AA                                                     1028
# AB                                                     2590
# AC                                                      932
# AD                                                      838
# AE                                                      743
#
#            Population: departures to Amsterdam (other area)  \
# Area code
# AA                                                     1062
# AB                                                     2684
# AC                                                     1105
# AD                                                      917
# AE                                                      879
#
#            Population: migration within area  Duration  of residence  \
# Area code
# AA                                       136                     9.6
# AB                                       446                     9.7
# AC                                       144                     7.9
# AD                                        98                     5.5
# AE                                       120                       6
#
#            Migration background: Unknown
# Area code
# AA                                     -
# AB                                     -
# AC                                     -
# AD                                     -
# AE                                     -
#
# [5 rows x 68 columns]

# %% [markdown]
# ### d. Income

# %%
df_income = pd.read_excel('data/Income.xlsx','data',index_col = 'Area code')
df_income.head()
# Out:
#           Geography                     Area  Year   theme  \
# Area code
# AA           Wijken          Haarlemmerbuurt  2021  Income
# AB           Wijken                  Jordaan  2021  Income
# AC           Wijken      Grachtengordel-West  2021  Income
# AD           Wijken  Burgwallen-Nieuwe Zijde  2021  Income
# AE           Wijken    Burgwallen-Oude Zijde  2021  Income
#
#           Mean disposable household income Income 1st quintile  \
# Area code
# AA                                   49800                  30
# AB                                   46700                  33
# AC                                   83300                  20
# AD                                   44300                  32
# AE                                   40800                  35
#
#           Income 2nd quintile Income 3rd quintile Income 4th quintile  \
# Area code
# AA                         20                  17                  13
# AB                         20                  17                  13
# AC                         16                  15                  16
# AD                         21                  19                  13
# AE                         22                  16                  13
#
#           Income 5th quintile  ...  \
# Area code                      ...
# AA                         21  ...
# AB                         17  ...
# AC                         33  ...
# AD                         15  ...
# AE                         13  ...
#
#           Househoulds children social welfare benefits  \
# Area code
# AA                                                  50
# AB                                                  55
# AC                                                   -
# AD                                                   -
# AE                                                  15
#
#           % Househoulds children social welfare benefits Disability benefits  \
# Area code
# AA                                                   7.4                 330
# AB                                                   4.7                 690
# AC                                                     -                  80
# AD                                                     -                  60
# AE                                                   8.6                  70
#
#           Disability benefits (%) Unemployment benefits  \
# Area code
# AA                            4.9                   200
# AB                            4.7                   510
# AC                            1.6                    90
# AD                            1.7                   130
# AE                            1.8                   130
#
#           Unemployment benefits (%) % economically independent men  \
# Area code
# AA                                3                             68
# AB                              3.4                             67
# AC                              1.8                             70
# AD                              3.7                             69
# AE                              3.3                             66
#
#           % economically indepdent women Social welfare Social welfare (%)
# Area code
# AA                                    62              -                  -
# AB                                    63              -                  -
# AC                                    61              -                  -
# AD                                    63              -                  -
# AE                                    54              -                  -
#
# [5 rows x 29 columns]

# %% [markdown]
# ### d. Geometry

# %%
df_map = gpd.read_file('data/wijks.csv',GEOM_POSSIBLE_NAMES="geometry", 
                    KEEP_GEOM_COLUMNS="NO")
df_map.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Step 2: Loading data
# ### lorem impsum
#
# lorem impsum

# %%
df = df_parking[['Parking spots total','Parking spots non public','Parking spots fiscal']]
df1 = df_housing[['Rent: average', 'Average number of residents']]
df2 = df_population[['Households: % single-parent family', 'Households: % single-person', 'Households: % couple without children', 'Households: % couple with children', 'Households: % other']]
#df3 = map[['Parking spots total','Parking spots non public','Parking spots fiscal']]

df = df.join(df1)
df = df.join(df2)
